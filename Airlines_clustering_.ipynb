# %%
# Importing libraries
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-334340f3-74a3-4ca0-b532-ac78e34d86a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-334340f3-74a3-4ca0-b532-ac78e34d86a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Reading dataset
airlines=pd.read_csv("EastWestAirlines.csv")

# %% [markdown]
# # EDA

# %%
airlines.shape
# Out:
# (3999, 12)

# %%
airlines.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airlines.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airlines.shape
# Out:
# (3999, 12)

# %%
#renaming the columns
airlines=airlines.rename({'ID#':'ID','Award?':'Award'},axis=1)

# %%
airlines
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines.set_index('ID')
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# ...

# %%
airlines.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
#checking sum of null values
airlines.isna().sum()
# Out:
# ID                   0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
#checking dummy variables
airlines.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3994    False
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# Length: 3999, dtype: bool

# %%
airlines[airlines.duplicated()].shape
# Out:
# (0, 12)

# %%
airlines.duplicated().sum()
# Out:
# 0

# %%
airlines.hist(figsize=(25,10))
plt.show()

# %%
plt.figure(figsize=(25,10))
import seaborn as sns
sns.boxplot(data=airlines)
plt.show()

# %%
sns.countplot(x='Award',data=airlines,order=airlines['Award'].value_counts().index)
plt.title('client has award or not')
# Out:
# Text(0.5, 1.0, 'client has award or not')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(airlines.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Hierarchical clustering

# %%
#Normalizing Data
def norm_func(i):
  x=(i-i.min())/(i.max()-i.min())
  return(x)

# %%
#considering numerical data
airlines_norm=norm_func(airlines)
airlines_norm
# Out:
#             ID   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
#creating dendrogram
#plt.figure(figsize=(10,7))
dendrogram=sch.dendrogram(sch.linkage(airlines_norm,method='single'))

# %%
dendrogram=sch.dendrogram(sch.linkage(airlines_norm,method='complete'))

# %%
dendrogram=sch.dendrogram(sch.linkage(airlines_norm,method='median'))

# %%
dendrogram=sch.dendrogram(sch.linkage(airlines_norm,method='average'))

# %%
#creating clusters
hc=AgglomerativeClustering(n_clusters=6,affinity='euclidean',linkage='complete')
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=6)

# %%
airlines.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
del airlines['ID']

# %%
airlines.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
#predicting hc norm
hc.fit(airlines_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=6)

# %%
y_hc = hc.fit_predict(airlines_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
clusters = pd.DataFrame(y_hc,columns=['clusters'])
y_hc
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %% [markdown]
# # K Means Clustering

# %%
#importing libraries
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#standardization of data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_airlines = scaler.fit_transform(airlines)

# %%
scaled_airlines
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
scaled_airlines = scaler.fit_transform(airlines.iloc[:,1:])
scaled_airlines
# Out:
# array([[-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#          1.39545434, -0.7669193 ],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#          1.37995704, -0.7669193 ],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#          1.41192021, -0.7669193 ],
#        ...,
#        [-0.18629869,  0.68312117, -0.09824189, ..., -0.36216787,
#         -1.31560393,  1.30391816],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.09850333,
#         -1.31608822, -0.7669193 ],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#         -1.31754109, -0.7669193 ]])

# %%
#normalization of data
airlines_norm = StandardScaler().fit_transform(airlines)

# %%
#Building elbow graph by using wcss to decide the k-value
#wcss-within cluster sum of squares
wcss = []
for i in range (1,11):
  kmeans = KMeans(n_clusters=i,random_state=0)
  kmeans.fit(airlines_norm)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
#Plotting elbow graph
plt.plot(range(1,11),wcss)
plt.title('Elbow Graph')
plt.xlabel('No of clusters')
plt.ylabel("wcss")
plt.show()

# %%
predict = kmeans.fit_predict(scaled_airlines)
predict
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 3, 6, 6], dtype=int32)

# %% [markdown]
# Building clusters by taking k=3

# %%
from sklearn.cluster import KMeans
cluster1 = KMeans(3,random_state=27)
cluster1.fit(airlines_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=27)

# %%
cluster1.labels_
# Out:
# array([2, 2, 2, ..., 0, 2, 2], dtype=int32)

# %%
#Assigning clusters to the dataset
airlines1 = airlines.copy()
airlines1['cluster1id'] = cluster1.labels_
airlines1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#calculating centroids for clusters
cluster1.cluster_centers_
# Out:
# array([[ 0.43048887,  0.01642516,  1.21446998, -0.08210144,  0.11218848,
#          0.96375606,  0.76629019, -0.08399898, -0.09536197,  0.3709822 ,
#          0.58512867],
#        [ 1.23330946,  0.82316979,  0.06616141,  0.14658734,  0.09152624,
#          0.59705278,  1.61043356,  3.50959072,  3.77863606,  0.29612364,
#          0.90472058],
#        [-0.29009901, -0.061121  , -0.59829079,  0.03070404, -0.06077648,
#         -0.50989885, -0.47866796, -0.18525149, -0.19704462, -0.20055288,
#         -0.34454569]])

# %%
#Grouping data
airlines1.groupby('cluster1id').agg(['mean'])
# Out:
#                   Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean        mean      mean      mean      mean
# cluster1id
# 0           116978.705322  156.820492  3.731533  1.002383  1.034154
# 1           197873.367470  780.891566  2.150602  1.036145  1.030120
# 2            44370.062160   96.833333  1.235820  1.019037  1.000389
#
#              Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#                     mean        mean              mean            mean
# cluster1id
# 0           40417.577442   18.960286        342.454329        1.011914
# 1           31562.445783   27.066265       5373.602410       15.704819
# 2            4831.835276    7.005439        200.697358        0.626263
#
#            Days_since_enroll     Award
#                         mean      mean
# cluster1id
# 0                4884.591739  0.652899
# 1                4730.018072  0.807229
# 2                3704.442502  0.203963

# %%
airlines1[airlines1['cluster1id']==0]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4       97752           0          4          1          1        43300
# 6       84914           0          3          1          1        27482
# 9      104860           0          3          1          1        28426
# 11      96522           0          5          1          1        61105
# 15      28495           0          4          1          1        49442
# ...       ...         ...        ...        ...        ...          ...
# 3979    57793           0          3          1          1        20959
# 3980    28867           0          3          1          1        19169
# 3985    59017           0          4          1          1        34746
# 3991    39142           0          3          1          1        14981
# 3996    73597           0          3          1          1        25447
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines1[airlines1['cluster1id']==1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8      443003           0          3          2          1         1753
# 21     185681        2024          1          1          1        13300
# 42      60313           0          1          1          1        10000
# 50     108137           0          1          1          1         6368
# 65      53914           0          3          1          1        33767
# ...       ...         ...        ...        ...        ...          ...
# 3907   126490           0          1          1          1         8808
# 3911    55922        2273          1          1          1         8104
# 3917   130748           0          4          1          1        65510
# 3934    76595           0          1          1          1        10577
# 3950    59650           0          1          1          1         5050
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines1[airlines1['cluster1id']==2]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 5       16420           0          1          1          1            0
# ...       ...         ...        ...        ...        ...          ...
# 3993     3974           0          1          1          1          365
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines1[airlines1['cluster1id']==3]
# Out:
# Empty DataFrame
# Columns: [Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award, cluster1id]
# Index: []

# %%
#plotting clusters
plt.figure(figsize=(5,5))
plt.scatter(airlines1['cluster1id'],airlines1['Balance'],c=cluster1.labels_)

# %% [markdown]
# Building clusters by taking k =  4

# %%
cluster2 = KMeans(4,random_state=48)
cluster2.fit(airlines_norm)
cluster2
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=48)

# %%
#creating labels
cluster2.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int32)

# %%
#Assigning clusters to the dataset
airlines2 = airlines.copy()
airlines2['cluster2id'] = cluster2.labels_
airlines2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#Computing clusters centroids
cluster2.cluster_centers_
# Out:
# array([[-2.98080806e-01, -5.97935733e-02, -6.14956551e-01,
#          3.28429580e-02, -6.07434671e-02, -5.18361639e-01,
#         -4.91614164e-01, -1.84016111e-01, -1.96596536e-01,
#         -2.07429997e-01, -3.48171756e-01],
#        [ 4.24503609e-01,  1.41198512e-02,  1.18273279e+00,
#         -8.25015105e-02, -5.48308378e-02,  8.98291475e-01,
#          7.40095954e-01, -8.35976054e-02, -9.54398392e-02,
#          3.67311215e-01,  5.64447928e-01],
#        [ 1.22428976e+00,  8.35000581e-01,  9.21160612e-02,
#          1.54190736e-01, -6.27665798e-02,  6.52807486e-01,
#          1.63716758e+00,  3.56120442e+00,  3.85155175e+00,
#          2.94508603e-01,  9.18047825e-01],
#        [ 6.39719256e-01, -8.44329231e-02,  1.02208440e+00,
#         -9.82418871e-02,  1.56462993e+01,  3.17969131e+00,
#          1.71461374e+00,  3.32926913e-02,  5.96953922e-02,
#          2.39872612e-01,  3.37527346e-01]])

# %%
#Grouping dataset
airlines2.groupby('cluster2id').agg(['mean'])
# Out:
#                   Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean        mean      mean      mean      mean
# cluster2id
# 0            43663.205047   97.705836  1.215694  1.019322  1.000394
# 1           116409.955711  155.519037  3.689977  1.002331  1.001554
# 2           196964.515528  790.043478  2.186335  1.037267  1.000000
# 3           138061.400000   78.800000  3.466667  1.000000  4.066667
#
#              Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#                     mean        mean              mean            mean
# cluster2id
# 0            4648.695978    6.894716        202.107650        0.626972
# 1           38901.251748   18.718726        344.082362        1.014763
# 2           32908.807453   27.322981       5445.863354       15.981366
# 3           93927.866667   28.066667        506.666667        1.600000
#
#            Days_since_enroll     Award
#                         mean      mean
# cluster2id
# ...

# %%
#plot clusters
plt.figure(figsize=(5,5))
plt.scatter(airlines2['cluster2id'],airlines2['Balance'],c=cluster2.labels_)

# %% [markdown]
# # DBSCAN Clustering

# %%
airlines2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
plt.scatter(airlines2['Balance'],airlines2['cc1_miles'],airlines2['cc2_miles'],airlines2['cc3_miles'])

# %%
array = airlines2.values

# %%
array
# Out:
# array([[28143,     0,     1, ...,  7000,     0,     0],
#        [19244,     0,     1, ...,  6968,     0,     0],
#        [41354,     0,     1, ...,  7034,     0,     0],
#        ...,
#        [73597,     0,     3, ...,  1402,     1,     1],
#        [54899,     0,     1, ...,  1401,     0,     0],
#        [ 3016,     0,     1, ...,  1398,     0,     0]])

# %%
stscaler = StandardScaler()
X = stscaler.fit_transform(array)

# %%
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.39545434e+00, -7.66919299e-01, -7.03592982e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.37995704e+00, -7.66919299e-01, -7.03592982e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.41192021e+00, -7.66919299e-01, -7.03592982e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -1.31560393e+00,  1.30391816e+00,  9.97536603e-01],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31608822e+00, -7.66919299e-01, -7.03592982e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31754109e+00, -7.66919299e-01, -7.03592982e-01]])

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=1,min_samples=6)
dbscan.fit(airlines_norm)
# Out:
# DBSCAN(eps=1, min_samples=6)

# %%
#labels
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
#clustering
cl = pd.DataFrame(dbscan.labels_,columns = ['cluster'])
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 3994        1
# 3995        1
# 3996        1
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
pd.concat([airlines2,cl],axis = 1)
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...
